# %%
import pandas as pd

# %%
df = pd.read_csv("Amazon_Sale_Report.csv")
# Out:
# C:\Users\praka\AppData\Local\Temp\ipykernel_8000\2249054188.py:1: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Amazon_Sale_Report.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  str
#  2   Date                128975 non-null  str
#  3   Status              128975 non-null  str
#  4   Fulfilment          128975 non-null  str
#  5   Sales Channel       128975 non-null  str
#  6   ship-service-level  128975 non-null  str
#  7   Style               128975 non-null  str
#  8   SKU                 128975 non-null  str
#  9   Category            128975 non-null  str
#  10  Size                128975 non-null  str
#  11  ASIN                128975 non-null  str
#  12  Courier Status      122103 non-null  str
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  str
#  15  Amount              121180 non-null  float64
# ...

# %%
print(df)
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.nunique().to_frame(name="Count of unique values")
# Out:
#                     Count of unique values
# index                               128975
# Order ID                            120378
# Date                                    91
# Status                                  13
# Fulfilment                               2
# Sales Channel                            2
# ship-service-level                       2
# Style                                 1377
# SKU                                   7195
# Category                                 9
# Size                                    11
# ASIN                                  7190
# Courier Status                           3
# Qty                                     10
# currency                                 1
# Amount                                1410
# ship-city                             8955
# ship-state                              69
# ship-postal-code                      9459
# ship-country                             1
# promotion-ids                         5787
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df=df.drop('Unnamed: 22', axis=1)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by'],
#       dtype='str')

# %%
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df["Courier Status"].head(20)
# Out:
# 0           NaN
# 1       Shipped
# 2       Shipped
# 3           NaN
# 4       Shipped
# 5       Shipped
# 6       Shipped
# 7       Shipped
# 8     Cancelled
# 9       Shipped
# 10      Shipped
# 11      Shipped
# 12      Shipped
# 13      Shipped
# 14      Shipped
# 15      Shipped
# 16      Shipped
# 17      Shipped
# 18      Shipped
# 19      Shipped
# Name: Courier Status, dtype: str

# %%
df["Courier Status"] = df["Courier Status"].fillna("unknown")

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status            0
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# dtype: int64

# %%
df["currency"].head()
# Out:
# 0    INR
# 1    INR
# 2    INR
# 3    INR
# 4    INR
# Name: currency, dtype: str

# %%
df["currency"] = df["currency"].fillna("unknown")
df["Amount"] = df["Amount"].fillna(0)
df["ship-city"] = df["ship-city"].fillna("unknown")
df["ship-state"] = df["ship-state"].fillna("unknown")
df["ship-postal-code"] = df["ship-postal-code"].fillna(0)
df["ship-country"] = df["ship-country"].fillna("unknown")
df["promotion-ids"] = df["promotion-ids"].fillna("no promotion")
df["fulfilled-by"] = df["fulfilled-by"].fillna("unknown")

# %%
df.columns = df.columns.str.strip()

column = {
    'index':'Index','Order ID':'Order_ID','Date':'date','Status':'Ship_status','Fulfilment':'fullfilment','Sales Channel ':'sales_channel',
    'ship-service-level':'Ship_service_level','Style':'style','SKU':'sku','Category':'Product_category','Size':'size',
    'ASIN':'asin','Courier Status':'courier_status','Qty':'quantity', 'currency':'currency','Amount':'order_amount',
    'ship-city':'city','ship-state':'state','ship-postal-code':'zip','ship-country':'country','promotion-ids':'promotion',
    'B2B':'customer_type','fulfilled-by':'fullfilled_type'
}

df = df.rename(columns=column)

# %%
df.isnull().sum()
# Out:
# Index                 0
# Order_ID              0
# date                  0
# Ship_status           0
# fullfilment           0
# Sales Channel         0
# Ship_service_level    0
# style                 0
# sku                   0
# Product_category      0
# size                  0
# asin                  0
# courier_status        0
# quantity              0
# currency              0
# order_amount          0
# city                  0
# state                 0
# zip                   0
# country               0
# promotion             0
# customer_type         0
# fullfilled_type       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Index               128975 non-null  int64
#  1   Order_ID            128975 non-null  str
#  2   date                128975 non-null  str
#  3   Ship_status         128975 non-null  str
#  4   fullfilment         128975 non-null  str
#  5   Sales Channel       128975 non-null  str
#  6   Ship_service_level  128975 non-null  str
#  7   style               128975 non-null  str
#  8   sku                 128975 non-null  str
#  9   Product_category    128975 non-null  str
#  10  size                128975 non-null  str
#  11  asin                128975 non-null  str
#  12  courier_status      128975 non-null  str
#  13  quantity            128975 non-null  int64
#  14  currency            128975 non-null  str
#  15  order_amount        128975 non-null  float64
# ...

# %%
df['customer_type'] = df['customer_type'].replace(to_replace=[True, False], value=['busincess', 'customer'])

# %%
df['customer_type']
# Out:
# 0          customer
# 1          customer
# 2         busincess
# 3          customer
# 4          customer
#             ...
# 128970     customer
# 128971     customer
# 128972     customer
# 128973     customer
# 128974     customer
# Name: customer_type, Length: 128975, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
# Out:
# C:\Users\praka\AppData\Local\Temp\ipykernel_8000\3532345252.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])

# %%
df.columns
# Out:
# Index(['Index', 'Order_ID', 'date', 'Ship_status', 'fullfilment',
#        'Sales Channel', 'Ship_service_level', 'style', 'sku',
#        'Product_category', 'size', 'asin', 'courier_status', 'quantity',
#        'currency', 'order_amount', 'city', 'state', 'zip', 'country',
#        'promotion', 'customer_type', 'fullfilled_type'],
#       dtype='str')

# %%
df.shape
# Out:
# (128975, 23)

# %%
print(df.columns.tolist())
# Out:
# ['Index', 'Order_ID', 'date', 'Ship_status', 'fullfilment', 'Sales Channel', 'Ship_service_level', 'style', 'sku', 'Product_category', 'size', 'asin', 'courier_status', 'quantity', 'currency', 'order_amount', 'city', 'state', 'zip', 'country', 'promotion', 'customer_type', 'fullfilled_type']

# %%
a = df.groupby('Ship_status')['Ship_status'].sum()
print(a)
# Out:
# Ship_status
# Pending - Waiting for Pick Up    Pending - Waiting for Pick UpPending - Waiting...
# cancel                           cancelcancelcancelcancelcancelcancelcancelcanc...
# damaged                                                                    damaged
# delivered                        delivereddelivereddelivereddelivereddeliveredd...
# dispatch                         dispatchdispatchdispatchdispatchdispatchdispat...
# lost                                                          lostlostlostlostlost
# pending                          pendingpendingpendingpendingpendingpendingpend...
# picked                           pickedpickedpickedpickedpickedpickedpickedpick...
# rejected                         rejectedrejectedrejectedrejectedrejectedreject...
# returned                         returnedreturnedreturnedreturnedreturnedreturn...
# shipped                          shippedshippedshippedshippedshippedshippedship...
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Order_ID', 'date', 'Ship_status', 'fullfilment',
#        'Sales Channel', 'Ship_service_level', 'style', 'sku',
#        'Product_category', 'size', 'asin', 'courier_status', 'quantity',
#        'currency', 'order_amount', 'city', 'state', 'zip', 'country',
#        'promotion', 'customer_type', 'fullfilled_type'],
#       dtype='str')

# %%
df['Ship_status'] = df['Ship_status'].replace({
'Cancelled': 'cancel',                        
'Pending':'pending',                          
'Pending - Waiting for Pick Up ':'waiting',   
'Shipped':'shipped' ,                       
'Shipped - Damaged':'damaged' ,                   
'Shipped - Delivered to Buyer':'delivered',     
'Shipped - Lost in Transit':'lost'    ,      
'Shipped - Out for Delivery': 'dispatch'   ,    
'Shipped - Picked Up':'picked'      ,      
'Shipped - Rejected by Buyer':'rejected' ,      
'Shipped - Returned to Seller':'returned' ,   
'Shipped - Returning to Seller':'returned'  ,  
'Shipping': 'shipping'
    }
    
)

# %%
revenue_by_category = df.groupby('Product_category')['order_amount'].sum().sort_values(ascending=False)
print(revenue_by_category)
print("\n")

percentage_by_product_category = ((revenue_by_category / revenue_by_category.sum()) * 100).round(2).astype(str) + '%'
print(percentage_by_product_category)
print("\n")

total_cancelled = df[df['Ship_status'] == 'cancel'].shape[0]
print('Total cancelled orders',total_cancelled)


total_retruned = df[df['Ship_status'] == 'returned'].shape[0]
print('Total returned orders',total_retruned)
# Out:
# Product_category
# Set              39204124.03
# kurta            21299546.70
# Western Dress    11216072.69
# Top               5347792.30
# Ethnic Dress       791217.66
# Blouse             458408.18
# Bottom             150667.98
# Saree              123933.76
# Dupatta               915.00
# Name: order_amount, dtype: float64
#
#
# Product_category
# Set              49.88%
# kurta             27.1%
# Western Dress    14.27%
# Top                6.8%
# Ethnic Dress      1.01%
# Blouse            0.58%
# Bottom            0.19%
# Saree             0.16%
# Dupatta            0.0%
# Name: order_amount, dtype: str
#
#
# Total cancelled orders 18332
# Total returned orders 2098

# %%
df.to_csv("cleaned_amazon.csv", index=False)
